# %% [markdown]
# # IRIS DataSet

# %%
#import the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# # EDA Analysis

# %%
#Import the data set from Desktop
dataset = pd.read_csv('iris.csv')

# %%
dataset
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Rename the Column labels 
dataset.rename(columns={'Sepal.Length': 'Sepal_Length',
                        'Sepal.Width': 'Sepal_Width',
                        'Petal.Length': 'Petal_Length',
                        'Petal.Width': 'Petal_Width'}, inplace=True)

# %%
#Return the first 5 rows.
dataset.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#Return the last 5 rows.
dataset.tail()
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width    Species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
#Return the random row.
dataset.sample()
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width    Species
# 140           6.7          3.1           5.6          2.4  virginica

# %%
#Return the shape of dataframe
dataset.shape
# Out:
# (150, 5)

# %%
#Check unique name of Species
dataset.Species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
#Check unique number of Species
dataset["Species"].nunique()
# Out:
# 3

# %%
#Check the concise summary of a dataset  
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal_Length  150 non-null    float64
#  1   Sepal_Width   150 non-null    float64
#  2   Petal_Length  150 non-null    float64
#  3   Petal_Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
#Check the describtive statistics in the dataset
dataset.describe()
# Out:
#        Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#Check the describtive statistics on Sepal_Length,Sepal_Width,Petal_Length and Petal_Width.

dataset.groupby("Species").describe().T
# Out:
# Species                setosa  versicolor  virginica
# Sepal_Length count  50.000000   50.000000  50.000000
#              mean    5.006000    5.936000   6.588000
#              std     0.352490    0.516171   0.635880
#              min     4.300000    4.900000   4.900000
#              25%     4.800000    5.600000   6.225000
#              50%     5.000000    5.900000   6.500000
#              75%     5.200000    6.300000   6.900000
#              max     5.800000    7.000000   7.900000
# Sepal_Width  count  50.000000   50.000000  50.000000
#              mean    3.418000    2.770000   2.974000
#              std     0.381024    0.313798   0.322497
#              min     2.300000    2.000000   2.200000
#              25%     3.125000    2.525000   2.800000
#              50%     3.400000    2.800000   3.000000
#              75%     3.675000    3.000000   3.175000
#              max     4.400000    3.400000   3.800000
# Petal_Length count  50.000000   50.000000  50.000000
# ...

# %%
dataset.groupby("Sepal_Length").describe().T
# Out:
# Sepal_Length        4.3           4.4  4.5       4.6       4.7       4.8  \
# Sepal_Width  count  1.0  3.000000e+00  1.0  4.000000  2.000000  5.000000
#              mean   3.0  3.033333e+00  2.3  3.325000  3.200000  3.180000
#              std    NaN  1.527525e-01  NaN  0.221736  0.000000  0.204939
#              min    3.0  2.900000e+00  2.3  3.100000  3.200000  3.000000
#              25%    3.0  2.950000e+00  2.3  3.175000  3.200000  3.000000
#              50%    3.0  3.000000e+00  2.3  3.300000  3.200000  3.100000
#              75%    3.0  3.100000e+00  2.3  3.450000  3.200000  3.400000
#              max    3.0  3.200000e+00  2.3  3.600000  3.200000  3.400000
# Petal_Length count  1.0  3.000000e+00  1.0  4.000000  2.000000  5.000000
#              mean   1.1  1.333333e+00  1.3  1.325000  1.450000  1.580000
#              std    NaN  5.773503e-02  NaN  0.221736  0.212132  0.204939
#              min    1.1  1.300000e+00  1.3  1.000000  1.300000  1.400000
# ...

# %%
#Return the correlation of dataset columns
dataset.corr()
# Out:
#               Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# Sepal_Length      1.000000    -0.109369      0.871754     0.817954
# Sepal_Width      -0.109369     1.000000     -0.420516    -0.356544
# Petal_Length      0.871754    -0.420516      1.000000     0.962757
# Petal_Width       0.817954    -0.356544      0.962757     1.000000

# %%
#Check the NaN values in dataset
dataset.isna().sum()
# Out:
# Sepal_Length    0
# Sepal_Width     0
# Petal_Length    0
# Petal_Width     0
# Species         0
# dtype: int64

# %%
#Calculate the mean of species
dataset.groupby("Species").apply(lambda x: np.mean(x))
# Out:
#             Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# Species
# setosa             5.006        3.418         1.464        0.244
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
#Plotting pairplot
sns.pairplot(dataset, hue='Species');

# %%
#Plotting the scatterplot graph between Sepal_Length & Sepal_Width
plt.figure(figsize=(12, 6))
plt.title('Sepal Dimensions');
sns.scatterplot(x=dataset.Sepal_Length,y=dataset.Sepal_Width,hue=dataset.Species,s=100);

# %%
#Plotting the scatterplot graph between Petal_Length & Petal_Width
plt.figure(figsize=(12, 6))
plt.title('Petal Dimensions');
sns.scatterplot(x=dataset.Petal_Length,y=dataset.Petal_Width,hue=dataset.Species,s=100);

# %%
#Rename the Species classifier 
setosa_df = dataset[dataset.Species == 'setosa']
versicolor_df = dataset[dataset.Species == 'versicolor']
virginica_df = dataset[dataset.Species == 'virginica']

# %%
#Plotting the Histogram graph on Species classifier
plt.figure(figsize=(12, 6))
plt.title('Distribution of Sepal Width')
plt.hist([setosa_df.Sepal_Width, versicolor_df.Sepal_Width, virginica_df.Sepal_Width], 
         bins=np.arange(2, 5, 0.25), 
         stacked=True);
plt.legend(['Setosa', 'Versicolor', 'Virginica']);

# %% [markdown]
# # Machine Learning using Linear Regression Classification

# %%
#Splitting the data into X and y
X=dataset.iloc[:,[0,1,2,3]].values
y=dataset.iloc[:,4].values

# %%
X
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
y
# Out:
# array(['setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
# ...

# %%
#Training and Testing Data (divide the data into two part)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =train_test_split(X,y,test_size=0.25, random_state=0)

# %%
X_train, X_test, y_train, y_test
# Out:
# (array([[5.9, 3. , 4.2, 1.5],
#         [5.8, 2.6, 4. , 1.2],
#         [6.8, 3. , 5.5, 2.1],
#         [4.7, 3.2, 1.3, 0.2],
#         [6.9, 3.1, 5.1, 2.3],
#         [5. , 3.5, 1.6, 0.6],
#         [5.4, 3.7, 1.5, 0.2],
#         [5. , 2. , 3.5, 1. ],
#         [6.5, 3. , 5.5, 1.8],
#         [6.7, 3.3, 5.7, 2.5],
#         [6. , 2.2, 5. , 1.5],
#         [6.7, 2.5, 5.8, 1.8],
#         [5.6, 2.5, 3.9, 1.1],
#         [7.7, 3. , 6.1, 2.3],
#         [6.3, 3.3, 4.7, 1.6],
#         [5.5, 2.4, 3.8, 1.1],
#         [6.3, 2.7, 4.9, 1.8],
#         [6.3, 2.8, 5.1, 1.5],
#         [4.9, 2.5, 4.5, 1.7],
#         [6.3, 2.5, 5. , 1.9],
#         [7. , 3.2, 4.7, 1.4],
#         [6.5, 3. , 5.2, 2. ],
#         [6. , 3.4, 4.5, 1.6],
#         [4.8, 3.1, 1.6, 0.2],
#         [5.8, 2.7, 5.1, 1.9],
#         [5.6, 2.7, 4.2, 1.3],
#         [5.6, 2.9, 3.6, 1.3],
#         [5.5, 2.5, 4. , 1.3],
#         [6.1, 3. , 4.6, 1.4],
#         [7.2, 3.2, 6. , 1.8],
#         [5.3, 3.7, 1.5, 0.2],
# ...

# %%
y_test
# Out:
# array(['virginica', 'versicolor', 'setosa', 'virginica', 'setosa',
#        'virginica', 'setosa', 'versicolor', 'versicolor', 'versicolor',
#        'virginica', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'setosa', 'versicolor', 'versicolor', 'setosa',
#        'setosa', 'virginica', 'versicolor', 'setosa', 'setosa',
#        'virginica', 'setosa', 'setosa', 'versicolor', 'versicolor',
#        'setosa', 'virginica', 'versicolor', 'setosa', 'virginica',
#        'virginica', 'versicolor', 'setosa', 'versicolor'], dtype=object)

# %%
#Normalize the values between 1 and -1
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Linear Regression Classification
from sklearn.linear_model import LogisticRegression
classifer = LogisticRegression(random_state=0)
classifer.fit(X_train,y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
#for predict the test values
y_pred= classifer.predict(X_test)
y_pred
# Out:
# array(['virginica', 'versicolor', 'setosa', 'virginica', 'setosa',
#        'virginica', 'setosa', 'versicolor', 'versicolor', 'versicolor',
#        'virginica', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'setosa', 'versicolor', 'versicolor', 'setosa',
#        'setosa', 'virginica', 'versicolor', 'setosa', 'setosa',
#        'virginica', 'setosa', 'setosa', 'versicolor', 'versicolor',
#        'setosa', 'virginica', 'versicolor', 'setosa', 'virginica',
#        'virginica', 'versicolor', 'setosa', 'virginica'], dtype=object)

# %%
#Checking the Confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[13,  0,  0],
#        [ 0, 15,  1],
#        [ 0,  0,  9]], dtype=int64)

# %%
#Plotting the Confusion matrix
plt.figure(figsize = (10,7))
sns.heatmap(cm, annot=True,cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Truth');

# %%
#Accuracy Score
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9736842105263158

# %%
#Classification Report
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        13
#   versicolor       1.00      0.94      0.97        16
#    virginica       0.90      1.00      0.95         9
#
#     accuracy                           0.97        38
#    macro avg       0.97      0.98      0.97        38
# weighted avg       0.98      0.97      0.97        38
